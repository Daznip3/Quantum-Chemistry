# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../beer_recipes_output.csv')

# %% [markdown]
# ### Проверка полноты и уникальности

# %%
print('Форма данных:', df.shape)
print('\nПропуски:\n', df.isnull().sum())
print('\nДубликаты:', df.duplicated().sum())
print('\nУникальные BeerID:', df['beerid'].nunique())
# Out:
# Форма данных: (73861, 25)
#
# Пропуски:
#  beerid                      0
# name                        2
# url                         0
# style                     596
# styleid                     0
# size(l)                     0
# og                          0
# fg                          0
# abv                         0
# ibu                         0
# color                       0
# boilsize                    0
# boiltime                    0
# boilgravity              2990
# efficiency                  0
# mashthickness           29864
# sugarscale                  0
# brewmethod                  0
# pitchrate               39252
# primarytemp             22662
# primingmethod           67101
# primingamount           69087
# priming_amount_value    72056
# priming_amount_unit     71745
# attenuation                 0
# dtype: int64
#
# Дубликаты: 0
#
# Уникальные BeerID: 73861

# %% [markdown]
# ### Распределение признаков

# %%
df.describe()  # Числовые
df.describe(include='object')  # Категориальные

# Гистограммы числовых
df.hist(figsize=(12,10), bins=20)
plt.show()

# Топ стилей
df['style'].value_counts().head(10).plot(kind='bar')
plt.title('Top styles')
plt.show()

df['brewmethod'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('BrewMethod')
plt.show()

# %% [markdown]
# ### Зависимости
