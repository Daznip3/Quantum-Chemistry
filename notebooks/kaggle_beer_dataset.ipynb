# %% [markdown]
# ## Import required libraries

# %%
import pandas as pd

# %% [markdown]
# ## Load the dataset

# %%
df = pd.read_csv('beer_recipes_output.csv')
df.head()
# Out:
#    beerid                             name  \
# 0       1                Vanilla Cream Ale
# 1       2      Southern Tier Pumking clone
# 2       3      Zombie Dust Clone - EXTRACT
# 3       4    Zombie Dust Clone - ALL GRAIN
# 4       5  Bakke Brygg Belgisk Blonde 50 l
#
#                                                  url  \
# 0       /homebrew/recipe/view/1633/vanilla-cream-ale
# 1  /homebrew/recipe/view/16367/southern-tier-pumk...
# 2  /homebrew/recipe/view/5920/zombie-dust-clone-e...
# 3  /homebrew/recipe/view/5916/zombie-dust-clone-a...
# 4  /homebrew/recipe/view/89534/bakke-brygg-belgis...
#
#                                 style  styleid  size(l)     og     fg   abv  \
# 0                           Cream Ale       45    21.77  1.055  1.013  5.48
# 1  Holiday/Winter Special Spiced Beer       85    20.82  1.083  1.021  8.16
# 2                        American Ipa        7    18.93  1.063  1.018  5.91
# ...

# %% [markdown]
# ## Basic dataset information

# %%
df.shape #посмотрел сколько строк и столбцов
# Out:
# (73861, 25)

# %%
df.info() #Узнал названия, тип переменной.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73861 entries, 0 to 73860
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   beerid                73861 non-null  int64
#  1   name                  73859 non-null  object
#  2   url                   73861 non-null  object
#  3   style                 73265 non-null  object
#  4   styleid               73861 non-null  int64
#  5   size(l)               73861 non-null  float64
#  6   og                    73861 non-null  float64
#  7   fg                    73861 non-null  float64
#  8   abv                   73861 non-null  float64
#  9   ibu                   73861 non-null  float64
#  10  color                 73861 non-null  float64
#  11  boilsize              73861 non-null  float64
#  12  boiltime              73861 non-null  int64
#  13  boilgravity           70871 non-null  float64
# ...

# %% [markdown]
# ## Descriptive statistics

# %%
descriptive_stats = df.describe()
descriptive_stats
# Out:
#              beerid       styleid       size(l)            og            fg  \
# count  73861.000000  73861.000000  73861.000000  73861.000000  73861.000000
# mean   36931.000000     60.179432     43.929775      1.406266      1.075865
# std    21321.978453     56.811462    180.373492      2.196908      0.432524
# min        1.000000      1.000000      1.000000      1.000000     -0.003000
# 25%    18466.000000     10.000000     18.930000      1.051000      1.011000
# 50%    36931.000000     35.000000     20.820000      1.058000      1.013000
# 75%    55396.000000    111.000000     23.660000      1.069000      1.017000
# max    73861.000000    176.000000   9200.000000     34.034500     23.424600
#
#                 abv           ibu         color      boilsize      boiltime  \
# count  73861.000000  73861.000000  73861.000000  73861.000000  73861.000000
# mean       6.136865     44.276186     13.404989     49.724919     65.074870
# ...

# %% [markdown]
# ## Missing value analysis

# %%
missing_counts = df.isnull().sum()
missing_counts
# Out:
# beerid                      0
# name                        2
# url                         0
# style                     596
# styleid                     0
# size(l)                     0
# og                          0
# fg                          0
# abv                         0
# ibu                         0
# color                       0
# boilsize                    0
# boiltime                    0
# boilgravity              2990
# efficiency                  0
# mashthickness           29864
# sugarscale                  0
# brewmethod                  0
# pitchrate               39252
# primarytemp             22662
# primingmethod           67101
# primingamount           69087
# priming_amount_value    72056
# priming_amount_unit     71745
# attenuation                 0
# dtype: int64

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage
# Out:
# beerid                   0.000000
# name                     0.002708
# url                      0.000000
# style                    0.806921
# styleid                  0.000000
# size(l)                  0.000000
# og                       0.000000
# fg                       0.000000
# abv                      0.000000
# ibu                      0.000000
# color                    0.000000
# boilsize                 0.000000
# boiltime                 0.000000
# boilgravity              4.048144
# efficiency               0.000000
# mashthickness           40.432705
# sugarscale               0.000000
# brewmethod               0.000000
# pitchrate               53.143066
# primarytemp             30.681957
# primingmethod           90.847673
# primingamount           93.536508
# priming_amount_value    97.556220
# priming_amount_unit     97.135159
# attenuation              0.000000
# dtype: float64

# %% [markdown]
# Из-за большого кол-ва пропущенных строк мы их просто удалим, тк занимают небольшой %.

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# beerid                  0
# name                    0
# url                     0
# style                   0
# styleid                 0
# size(l)                 0
# og                      0
# fg                      0
# abv                     0
# ibu                     0
# color                   0
# boilsize                0
# boiltime                0
# boilgravity             0
# efficiency              0
# mashthickness           0
# sugarscale              0
# brewmethod              0
# pitchrate               0
# primarytemp             0
# primingmethod           0
# primingamount           0
# priming_amount_value    0
# priming_amount_unit     0
# attenuation             0
# dtype: int64

# %% [markdown]
# ## Key statistics

# %%
summary_table = pd.DataFrame({
'Mean': df.mean(numeric_only=True),
'Median': df.median(numeric_only=True),
'Minimum': df.min(numeric_only=True),
'Maximum': df.max(numeric_only=True),
})


summary_table
# Out:
#                               Mean        Median    Minimum       Maximum
# beerid                31545.143119  29152.000000  36.000000  72614.000000
# styleid                  65.987156     45.000000   1.000000    175.000000
# size(l)                  25.684826     20.820000   3.790000    950.000000
# og                        1.309982      1.060000   1.025000     19.809700
# fg                        1.055225      1.014000   1.002000      5.213610
# abv                       6.224587      5.970000   2.490000     12.940000
# ibu                      42.998275     35.890000   0.000000    244.520000
# color                    14.290330      9.590000   2.190000     50.000000
# boilsize                 31.930991     28.000000   4.540000    953.000000
# boiltime                 68.491743     60.000000   0.000000    120.000000
# boilgravity               1.242657      1.046000   0.000000     21.700000
# efficiency               70.834495     70.000000  35.000000    100.000000
# ...

# %% [markdown]
# ## Uniqueness analysis

# %%
unique_counts = df.nunique()
unique_counts
# Out:
# beerid                  545
# name                    528
# url                     545
# style                   105
# styleid                 105
# size(l)                  81
# og                       79
# fg                       42
# abv                     322
# ibu                     515
# color                   452
# boilsize                147
# boiltime                 13
# boilgravity              72
# efficiency               40
# mashthickness            75
# sugarscale                2
# brewmethod                1
# pitchrate                 9
# primarytemp              47
# primingmethod            83
# primingamount           265
# priming_amount_value    141
# priming_amount_unit      68
# attenuation             344
# dtype: int64

# %%
unique_percentage = (unique_counts / len(df)) * 100
unique_percentage
# Out:
# beerid                  100.000000
# name                     96.880734
# url                     100.000000
# style                    19.266055
# styleid                  19.266055
# size(l)                  14.862385
# og                       14.495413
# fg                        7.706422
# abv                      59.082569
# ibu                      94.495413
# color                    82.935780
# boilsize                 26.972477
# boiltime                  2.385321
# boilgravity              13.211009
# efficiency                7.339450
# mashthickness            13.761468
# sugarscale                0.366972
# brewmethod                0.183486
# pitchrate                 1.651376
# primarytemp               8.623853
# primingmethod            15.229358
# primingamount            48.623853
# priming_amount_value     25.871560
# priming_amount_unit      12.477064
# attenuation              63.119266
# dtype: float64

# %% [markdown]
# После анализа на уникальность было выявлено, что в разных рецептах фигурируют одинаковые компоненты (например начальная и конечная плотность (fg) и тд .

# %%
full_duplicates = df.duplicated().sum()
full_duplicates
# Out:
# np.int64(0)

# %% [markdown]
# После анализа на полную уникальность дубликатов не нашлось
